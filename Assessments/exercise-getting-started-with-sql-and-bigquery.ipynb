# %% [markdown]
# **[SQL Home Page](https://www.kaggle.com/learn/intro-to-sql)**
#
# ---

# %% [markdown]
# # Introduction
#
# The first test of your new data exploration skills uses data describing crime in the city of Chicago.
#
# Before you get started, run the following cell. It sets up the automated feedback system to review your answers.

# %%
# Set up feedack system
from learntools.core import binder
binder.bind(globals())
from learntools.sql.ex1 import *
print("Setup Complete")
# Out:
# Using Kaggle's public dataset BigQuery integration.
# Setup Complete

# %% [markdown]
# Use the next code cell to fetch the dataset.

# %%
from google.cloud import bigquery

# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "chicago_crime" dataset
dataset_ref = client.dataset("chicago_crime", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)
# Out:
# Using Kaggle's public dataset BigQuery integration.

# %% [markdown]
# # Exercises
#
# ### 1) Count tables in the dataset
#
# How many tables are in the Chicago Crime dataset?

# %%
tables = list(client.list_tables(dataset)) # Write the code you need here to figure out the answer
# Out:
# 1

# %%
num_tables = len(tables)  # Store the answer as num_tables and then run this cell

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_1.hint()
#q_1.solution()

# %% [markdown]
# ### 2) Explore the table schema
#
# How many columns in the `crime` table have `TIMESTAMP` data?

# %%
table_ref = dataset_ref.table("crime")

table = client.get_table(table_ref)
client.list_rows(table, max_results=5).to_dataframe() # Write the code to figure out the answer
# Out:
#    unique_key case_number                      date                block  \
# 0    11640612    JC206563 2018-06-01 00:01:00+00:00  067XX W RASCHER AVE
# 1    10368970    HZ104966 2006-06-29 00:01:00+00:00  085XX S ANTHONY AVE
# 2     2349445    HH640832 2002-09-11 12:53:00+00:00  104XX S CORLISS AVE
# 3     7413118    HS215392 2005-01-16 00:01:00+00:00      039XX W 58TH PL
# 4     5254537    HN125192 2006-10-10 15:00:00+00:00   066XX W BELDEN AVE
#
#    iucr        primary_type                              description  \
# 0  1153  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1  1154  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2  1812           NARCOTICS           POSS: CANNABIS MORE THAN 30GMS
# 3  1562         SEX OFFENSE                AGG CRIMINAL SEXUAL ABUSE
# 4  1195  DECEPTIVE PRACTICE           FINAN EXPLOIT-ELDERLY/DISABLED
#
#   location_description  arrest  domestic  ...  ward  community_area  fbi_code  \
# 0            RESIDENCE   False     False  ...    41              10        11
# 1            RESIDENCE   False     False  ...     8              45        11
# 2   GROCERY FOOD STORE    True     False  ...     9              50        18
# 3            RESIDENCE   False     False  ...    13              62        17
# 4            APARTMENT   False     False  ...    36              18        11
#
#    x_coordinate y_coordinate  year                updated_on  latitude  \
# 0          None         None  2018 2019-04-01 16:21:13+00:00      None
# 1          None         None  2006 2016-01-10 08:46:55+00:00      None
# 2          None         None  2002 2015-08-17 15:03:40+00:00      None
# 3          None         None  2005 2015-08-17 15:03:40+00:00      None
# 4          None         None  2006 2015-08-17 15:03:40+00:00      None
#
#   longitude location
# 0      None     None
# 1      None     None
# 2      None     None
# 3      None     None
# 4      None     None
#
# [5 rows x 22 columns]

# %%
num_timestamp_fields = 2 # Put your answer here

# Check your answer
q_2.check()
# Out:
# Correct

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_2.hint()
q_2.solution()
# Out:
# Solution:
# ```python
#
# # Construct a reference to the "crime" table
# table_ref = dataset_ref.table("crime")
#
# # API request - fetch the table
# table = client.get_table(table_ref)
#
# # Print information on all the columns in the "crime" table in the "chicago_crime" dataset
# print(table.schema)
#
# num_timestamp_fields = 2
#
# ```

# %% [markdown]
# ### 3) Create a crime map
#
# If you wanted to create a map with a dot at the location of each crime, what are the names of the two fields you likely need to pull out of the `crime` table to plot the crimes on a map?

# %%
# Write the code here to explore the data so you can find the answer

# %%
fields_for_plotting = ['latitude', 'longitude'] # Put your answers here

# Check your answer
q_3.check()
# Out:
# Correct

# %% [markdown]
# For a hint or the solution, uncomment the appropriate line below.

# %%
#q_3.hint()
q_3.solution()
# Out:
# Solution:
# ```python
# fields_for_plotting = ['latitude', 'longitude']
# ```

# %% [markdown]
# Thinking about the question above, there are a few columns that appear to have geographic data. Look at a few values (with the `list_rows()` command) to see if you can determine their relationship.  Two columns will still be hard to interpret. But it should be obvious how the `location` column relates to `latitude` and `longitude`.

# %%
client.list_rows(table, max_results=25).to_dataframe()
# Scratch space for your code
# Out:
#     unique_key case_number                      date                   block  \
# 0     11640612    JC206563 2018-06-01 00:01:00+00:00     067XX W RASCHER AVE
# 1     10368970    HZ104966 2006-06-29 00:01:00+00:00     085XX S ANTHONY AVE
# 2      2349445    HH640832 2002-09-11 12:53:00+00:00     104XX S CORLISS AVE
# 3      7413118    HS215392 2005-01-16 00:01:00+00:00         039XX W 58TH PL
# 4      5254537    HN125192 2006-10-10 15:00:00+00:00      066XX W BELDEN AVE
# 5      5930040    HN725837 2002-10-15 22:00:00+00:00      056XX S KOLMAR AVE
# 6      6249110    HP336416 2008-05-14 18:30:00+00:00        131XX S AVENUE O
# 7      6638261    HP711119 2005-08-30 00:00:00+00:00         028XX E 94TH ST
# 8     10446808    HZ185775 2015-10-27 00:01:00+00:00      097XX S OAKLEY AVE
# 9     10462112    HZ201025 2015-10-29 00:01:00+00:00         049XX W 63RD ST
# 10     9674801    HX289463 2014-06-03 13:00:00+00:00         038XX W 57TH ST
# 11    11703579    JC282786 2019-05-29 04:20:00+00:00  035XX S WINCHESTER AVE
# 12    11711741    JC292871 2019-06-05 07:35:00+00:00   065XX W BRYN MAWR AVE
# 13    11715003    JC297045 2019-06-08 01:06:00+00:00      032XX S PAULINA ST
# 14    11720721    JC303966 2019-06-12 21:15:00+00:00      058XX N ELSTON AVE
# 15    11727164    JC311044 2019-06-17 14:00:00+00:00        096XX S AVENUE L
# 16    11736407    JC322894 2019-06-14 08:00:00+00:00     080XX S ANTHONY AVE
# 17    11764455    JC355656 2019-07-05 12:00:00+00:00    086XX S JEFFERY BLVD
# 18    11782621    JC377983 2019-06-04 10:05:00+00:00         014XX E 86th st
# 19    11781740    JC377553 2019-08-04 01:09:00+00:00      092XX S HARPER AVE
# 20    11787078    JC383711 2019-08-08 09:52:00+00:00    042XX W PETERSON AVE
# 21    11813912    JC415708 2019-09-01 06:20:00+00:00        007XX E 104TH PL
# 22    11815991    JC418215 2019-09-03 07:55:00+00:00       002XX W CERMAK RD
# 23    11837748    JC444624 2019-09-23 06:52:00+00:00   048XX N MC VICKER AVE
# 24    11888896    JC507020 2019-11-09 21:00:00+00:00    048XX S KOMENSKY AVE
#
#     iucr                primary_type  \
# 0   1153          DECEPTIVE PRACTICE
# 1   1154          DECEPTIVE PRACTICE
# 2   1812                   NARCOTICS
# 3   1562                 SEX OFFENSE
# 4   1195          DECEPTIVE PRACTICE
# 5   1754  OFFENSE INVOLVING CHILDREN
# 6   0915         MOTOR VEHICLE THEFT
# 7   0842                       THEFT
# 8   1120          DECEPTIVE PRACTICE
# 9   1154          DECEPTIVE PRACTICE
# 10  2091                   NARCOTICS
# 11  0330                     ROBBERY
# 12  0530                     ASSAULT
# 13  141A           WEAPONS VIOLATION
# 14  2826               OTHER OFFENSE
# 15  0498                     BATTERY
# 16  1153          DECEPTIVE PRACTICE
# 17  1790  OFFENSE INVOLVING CHILDREN
# 18  1153          DECEPTIVE PRACTICE
# 19  141B           WEAPONS VIOLATION
# 20  1140          DECEPTIVE PRACTICE
# 21  0326                     ROBBERY
# 22  1305             CRIMINAL DAMAGE
# 23  1360           CRIMINAL TRESPASS
# 24  0281         CRIM SEXUAL ASSAULT
#
#                                           description  \
# 0                 FINANCIAL IDENTITY THEFT OVER $ 300
# 1             FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2                      POSS: CANNABIS MORE THAN 30GMS
# 3                           AGG CRIMINAL SEXUAL ABUSE
# 4                      FINAN EXPLOIT-ELDERLY/DISABLED
# 5                      AGG SEX ASSLT OF CHILD FAM MBR
# 6                              TRUCK, BUS, MOTOR HOME
# 7                             AGG: FINANCIAL ID THEFT
# 8                                             FORGERY
# 9             FINANCIAL IDENTITY THEFT $300 AND UNDER
# 10                                   FORFEIT PROPERTY
# 11                                         AGGRAVATED
# 12                      AGGRAVATED: OTHER DANG WEAPON
# 13                               UNLAWFUL USE HANDGUN
# 14                     HARASSMENT BY ELECTRONIC MEANS
# 15  AGGRAVATED DOMESTIC BATTERY: HANDS/FIST/FEET S...
# 16                FINANCIAL IDENTITY THEFT OVER $ 300
# 17                                    CHILD ABDUCTION
# 18                FINANCIAL IDENTITY THEFT OVER $ 300
# 19                         UNLAWFUL USE OTHER FIREARM
# 20                                       EMBEZZLEMENT
# 21                     AGGRAVATED VEHICULAR HIJACKING
# 22                                CRIMINAL DEFACEMENT
# 23                                         TO VEHICLE
# 24                                     NON-AGGRAVATED
#
#               location_description  arrest  domestic  ...  ward  \
# 0                        RESIDENCE   False     False  ...    41
# 1                        RESIDENCE   False     False  ...     8
# 2               GROCERY FOOD STORE    True     False  ...     9
# 3                        RESIDENCE   False     False  ...    13
# 4                        APARTMENT   False     False  ...    36
# 5                        RESIDENCE   False      True  ...    13
# 6   PARKING LOT/GARAGE(NON.RESID.)   False     False  ...    10
# 7                        RESIDENCE   False     False  ...    10
# 8                        RESIDENCE   False     False  ...    19
# 9                            OTHER   False     False  ...    13
# 10                          STREET    True     False  ...    13
# 11                          STREET   False     False  ...    12
# 12        SCHOOL, PUBLIC, BUILDING    True     False  ...    41
# 13                           ALLEY   False     False  ...    12
# 14                       APARTMENT   False      True  ...    45
# 15                       APARTMENT   False      True  ...    10
# 16                          STREET   False     False  ...     8
# 17                       RESIDENCE   False     False  ...     8
# 18                            None   False     False  ...     8
# 19                          STREET   False     False  ...     8
# 20         MEDICAL / DENTAL OFFICE   False     False  ...    39
# 21                          STREET   False     False  ...     9
# 22                            BANK   False     False  ...    25
# 23                          STREET   False     False  ...    45
# 24                       RESIDENCE   False     False  ...    14
#
#     community_area  fbi_code  x_coordinate y_coordinate  year  \
# 0               10        11           NaN          NaN  2018
# 1               45        11           NaN          NaN  2006
# 2               50        18           NaN          NaN  2002
# 3               62        17           NaN          NaN  2005
# 4               18        11           NaN          NaN  2006
# 5               62        02           NaN          NaN  2002
# 6               55        07           NaN          NaN  2008
# 7               48        06           NaN          NaN  2005
# 8               72        10           NaN          NaN  2015
# 9               64        11           NaN          NaN  2015
# 10              62        18           NaN          NaN  2014
# 11              59        03     1163929.0    1881313.0  2019
# 12              10       04A     1131583.0    1936817.0  2019
# 13              59        15     1165546.0    1883172.0  2019
# 14              11        26     1136193.0    1938777.0  2019
# 15              52       04B     1201786.0    1841740.0  2019
# 16              45        11     1188162.0    1852229.0  2019
# 17              45        26     1191016.0    1848100.0  2019
# 18              45        11     1187499.0    1848251.0  2019
# 19              48        15     1188061.0    1844024.0  2019
# 20              12        12     1147126.0    1939540.0  2019
# 21              50        03     1182966.0    1835822.0  2019
# 22              34        14     1174916.0    1889739.0  2019
# 23              11        26     1134856.0    1931885.0  2019
# 24              57        02     1150178.0    1872292.0  2019
#
#                   updated_on   latitude  longitude  \
# 0  2019-04-01 16:21:13+00:00        NaN        NaN
# 1  2016-01-10 08:46:55+00:00        NaN        NaN
# 2  2015-08-17 15:03:40+00:00        NaN        NaN
# 3  2015-08-17 15:03:40+00:00        NaN        NaN
# 4  2015-08-17 15:03:40+00:00        NaN        NaN
# 5  2015-08-17 15:03:40+00:00        NaN        NaN
# 6  2015-08-17 15:03:40+00:00        NaN        NaN
# 7  2015-08-17 15:03:40+00:00        NaN        NaN
# 8  2018-02-09 15:44:29+00:00        NaN        NaN
# 9  2018-02-09 15:44:29+00:00        NaN        NaN
# 10 2018-04-14 15:49:16+00:00        NaN        NaN
# 11 2019-06-30 15:56:27+00:00  41.829949 -87.674048
# 12 2019-06-30 15:56:27+00:00  41.982879 -87.791441
# 13 2019-06-30 15:56:27+00:00  41.835016 -87.668062
# 14 2019-06-30 15:56:27+00:00  41.988176 -87.774439
# 15 2019-06-30 15:56:27+00:00  41.720477 -87.536498
# 16 2019-06-30 15:56:27+00:00  41.749595 -87.586065
# 17 2019-07-24 16:15:49+00:00  41.738196 -87.575740
# 18 2019-08-07 15:58:37+00:00  41.738695 -87.588621
# 19 2019-08-11 16:09:37+00:00  41.727082 -87.586696
# 20 2020-05-13 15:47:44+00:00  41.990067 -87.734206
# 21 2019-10-02 16:13:24+00:00  41.704695 -87.605614
# 22 2019-09-10 16:17:45+00:00  41.852832 -87.633485
# 23 2019-09-30 16:16:28+00:00  41.969287 -87.779521
# 24 2019-11-16 15:49:16+00:00  41.805472 -87.724735
#
#                          location
# 0                            None
# 1                            None
# 2                            None
# 3                            None
# 4                            None
# 5                            None
# 6                            None
# 7                            None
# 8                            None
# 9                            None
# 10                           None
# 11  (41.829948685, -87.674047724)
# 12   (41.98287878, -87.791440835)
# 13  (41.835015766, -87.668062122)
# 14    (41.9881759, -87.774438929)
# 15  (41.720477181, -87.536498395)
# 16   (41.749595265, -87.58606535)
# 17   (41.73819642, -87.575740495)
# 18  (41.738695015, -87.588620975)
# 19  (41.727082329, -87.586696298)
# 20  (41.990066798, -87.734206319)
# 21  (41.704694791, -87.605613693)
# 22  (41.852831845, -87.633484678)
# 23  (41.969287468, -87.779520508)
# 24  (41.805472302, -87.724735026)
#
# [25 rows x 22 columns]

# %% [markdown]
# # Keep going
#
# You've looked at the schema, but you haven't yet done anything exciting with the data itself. Things get more interesting when you get to the data, so keep going to **[write your first SQL query](https://www.kaggle.com/dansbecker/select-from-where).**

# %% [markdown]
# ---
# **[SQL Home Page](https://www.kaggle.com/learn/intro-to-sql)**
#
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161314) to chat with other Learners.*
